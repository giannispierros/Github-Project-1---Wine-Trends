# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from datetime import datetime, timedelta
pd.set_option('display.max_columns', None)
import re

# %%
df_red = pd.read_csv('Red.csv', low_memory=False)
df_red.head()
# Out:
#                                  Name  Country     Region  \
# 0                        Pomerol 2011   France    Pomerol
# 1                          Lirac 2017   France      Lirac
# 2  Erta e China Rosso di Toscana 2015    Italy    Toscana
# 3                      Bardolino 2019    Italy  Bardolino
# 4      Ried Scheibner Pinot Noir 2016  Austria  Carnuntum
#
#                   Winery  Rating  NumberOfRatings  Price  Year
# 0  Château La Providence     4.2              100  95.00  2011
# 1     Château Mont-Redon     4.3              100  15.50  2017
# 2             Renzo Masi     3.9              100   7.45  2015
# 3             Cavalchina     3.5              100   8.72  2019
# 4            Markowitsch     3.9              100  29.15  2016

# %%
df_red.shape
# Out:
# (8666, 8)

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8666 entries, 0 to 8665
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             8666 non-null   object
#  1   Country          8666 non-null   object
#  2   Region           8666 non-null   object
#  3   Winery           8666 non-null   object
#  4   Rating           8666 non-null   float64
#  5   NumberOfRatings  8666 non-null   int64
#  6   Price            8666 non-null   float64
#  7   Year             8666 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 541.8+ KB

# %%
df_red['Year'] = df_red['Year'].apply(pd.to_numeric, errors='coerce')
df_red.sort_values('Year', ascending = False)
# Out:
#                                          Name       Country  \
# 3586                         Tempranillo 2019         Spain
# 986                          The Guv’nor 2019         Spain
# 5407                        Nero d'Avola 2019         Italy
# 7553                  Cabernet Sauvignon 2019  South Africa
# 4287                    Vineyards Malbec 2019     Argentina
# ...                                       ...           ...
# 2201                Cinquanta Collezione N.V.         Italy
# 2404        Limited Edition 10 Vendemmie N.V.         Italy
# 4527            Lambrusco Reggiano Dolce N.V.         Italy
# 4833    Little James' Basket Press Rouge N.V.        France
# 5632  Tre Autoctoni Evoluzione Notturnia N.V.         Italy
#
#                        Region                  Winery  Rating  \
# 3586                La Mancha          Bodegas Artero     3.8
# 986                Valdepeñas             Félix Solís     4.0
# 5407          Terre Siciliane                Cusumano     3.4
# 7553             Western Cape             Golden Kaan     3.3
# 4287                  Mendoza                Trapiche     3.5
# ...                       ...                     ...     ...
# 2201            Vino d'Italia             San Marzano     4.3
# 2404  Montepulciano d'Abruzzo           Tenuta Ulisse     4.6
# 4527                 Reggiano                 Riunite     3.7
# 4833            Vin de France  Château de Saint Cosme     3.6
# 5632            Vino d'Italia                 Farnese     3.7
#
#       NumberOfRatings  Price    Year
# 3586               29   4.99  2019.0
# 986              1333   6.20  2019.0
# 5407               44   8.69  2019.0
# 7553               74   5.79  2019.0
# 4287             3393   4.78  2019.0
# ...               ...    ...     ...
# 2201            19454  16.38     NaN
# 2404             2080  30.90     NaN
# 4527              359   5.89     NaN
# 4833             3818   7.90     NaN
# 5632              461   7.75     NaN
#
# [8666 rows x 8 columns]

# %%
df_red.dropna(inplace = True)
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8658 entries, 0 to 8665
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             8658 non-null   object
#  1   Country          8658 non-null   object
#  2   Region           8658 non-null   object
#  3   Winery           8658 non-null   object
#  4   Rating           8658 non-null   float64
#  5   NumberOfRatings  8658 non-null   int64
#  6   Price            8658 non-null   float64
#  7   Year             8658 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 608.8+ KB
